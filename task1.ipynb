# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
url ="C:\\Users\\SUVARCHALA\\OneDrive\\Documents\\titanic data.csv"
df = pd.read_csv(url, skiprows=4)

# %%
df.head()
# Out:
#    4  1  1.1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35  \
# 0  5  0    3                           Allen, Mr. William Henry    male  35.0
# 1  6  0    3                                   Moran, Mr. James    male   NaN
# 2  7  0    1                            McCarthy, Mr. Timothy J    male  54.0
# 3  8  0    3                     Palsson, Master. Gosta Leonard    male   2.0
# 4  9  1    3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
#
#    1.2  0  113803     53.1 C123  S
# 0    0  0  373450   8.0500  NaN  S
# 1    0  0  330877   8.4583  NaN  Q
# 2    0  0   17463  51.8625  E46  S
# 3    3  1  349909  21.0750  NaN  S
# 4    0  2  347742  11.1333  NaN  S

# %%
df.shape
# Out:
# (887, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 12 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   4                                             887 non-null    int64
#  1   1                                             887 non-null    int64
#  2   1.1                                           887 non-null    int64
#  3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  887 non-null    object
#  4   female                                        887 non-null    object
#  5   35                                            710 non-null    float64
#  6   1.2                                           887 non-null    int64
#  7   0                                             887 non-null    int64
#  8   113803                                        887 non-null    object
# ...

# %%
df.tail()
# Out:
#        4  1  1.1 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    35  \
# 882  887  0    2                        Montvila, Rev. Juozas    male  27.0
# 883  888  1    1                 Graham, Miss. Margaret Edith  female  19.0
# 884  889  0    3     Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 885  890  1    1                        Behr, Mr. Karl Howell    male  26.0
# 886  891  0    3                          Dooley, Mr. Patrick    male  32.0
#
#      1.2  0      113803   53.1  C123  S
# 882    0  0      211536  13.00   NaN  S
# 883    0  0      112053  30.00   B42  S
# 884    1  2  W./C. 6607  23.45   NaN  S
# 885    0  0      111369  30.00  C148  C
# 886    0  0      370376   7.75   NaN  Q

# %%
df.describe()
# Out:
#                 4           1         1.1          35         1.2           0  \
# count  887.000000  887.000000  887.000000  710.000000  887.000000  887.000000
# mean   448.000000    0.382187    2.310034   29.696014    0.521984    0.383315
# std    256.199141    0.486196    0.835000   14.559186    1.104741    0.807466
# min      5.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    226.500000    0.000000    2.000000   20.000000    0.000000    0.000000
# 50%    448.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    669.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              53.1
# count  887.000000
# mean    32.192098
# std     49.769476
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %% [markdown]
# **Histogram for Age Distribution**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the Titanic dataset from Seaborn's built-in datasets
df = sns.load_dataset('titanic')

# Create the plot
plt.figure(figsize=(10, 6))
sns.histplot(df['age'].dropna(), bins=30, kde=True, color='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\SUVARCHALA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Bar Chart for Gender Distribution**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the Titanic dataset from Seaborn's built-in datasets
df = sns.load_dataset('titanic')

# Create the plot with custom colors
plt.figure(figsize=(10, 6))
sns.countplot(x='sex', data=df, palette=['#3498db', '#e74c3c'])  # Custom colors
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
